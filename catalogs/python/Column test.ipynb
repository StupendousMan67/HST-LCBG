# %% [markdown]
# # Cross reference Capak and Hunt catalogs
#
# GDW / 2018apr12

# %%
# %matplotlib inline

from astropy.io import ascii    
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read COSMOS catalog

# %%
cosmos_infile = '../Capak/deimos_redshifts.tbl'

# %%
cosmos = ascii.read( cosmos_infile)

# %%
cosmos.info
# Out:
# <Table masked=True length=10770>
#   name   dtype  n_bad
# ------- ------- -----
#      ID    str8   216
#      ra float64     0
#     dec float64     0
#     sel   int64     0
#    imag float64   125
#    kmag float64   485
#   zspec float64  2240
#   Qflag   int64     0
#       Q float64     0
# Remarks   str70  3533

# %%
plt.figure(figsize=(14,8))
plt.plot( cosmos['ra'], cosmos['dec'], 'r.' )

# %%
print cosmos['ra']
# Out:
#      ra
# -----------
#  149.358553
#  149.366394
# 149.3690949
#   149.37375
# 149.3740997
# 149.3744965
# 149.3755035
#  149.377594
# 149.3811035
# 149.3820953
#         ...
# 150.8035583
# 150.8054047
# 150.8085327
# 150.8104248
# 150.8167114
#  150.817749
# 150.8190918
# 150.8242493
# 150.8267365
# 150.8373566
# 150.8376007
# Length = 10770 rows

# %% [raw]
# ra  = cosmos['ra']
# print ra

# %% [raw]
# ra  = cosmos['ra'].copy()
# print ra

# %%
ra = np.array(cosmos['ra'])
print ra
# Out:
# [ 149.358553   149.366394   149.3690949 ...,  150.8267365  150.8373566
#   150.8376007]

# %%
print ra
# Out:
# [ 149.358553   149.366394   149.3690949 ...,  150.8267365  150.8373566
#   150.8376007]

# %%
dec = np.array(cosmos['dec'])
print dec
# Out:
# [ 2.750301   2.376694   2.3440881 ...,  2.879705   2.930975   2.9305582]
